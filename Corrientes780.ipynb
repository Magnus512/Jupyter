# %%
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from datetime import datetime
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
#import scipy

# %%
dataframe=pd.read_csv('Files/7800411.csv')

#print(dataframe)

tiempo = dataframe['Tiempo']
corriente = dataframe['Corriente']
voltaje = dataframe['Voltaje']
corriente = corriente.to_numpy()
voltaje = voltaje.to_numpy()
corriente = corriente*1000

# %%
#plt.figure(figsize=(20,10))
#plt.xticks(rotation=90)
#plt.tick_params(axis='x',labelsize = 15)
#axes = plt.axes()
#axes.set_xticklabels(tiempo,rotation = 45)
#axes.xaxis.set_tick_params(labelsize = 15)
#axes.set_xlim('5:44','5:50')
#axes.xaxis.set_major_locator(ticker.AutoLocator())
#axes.xaxis.set_minor_locator(ticker.AutoLocator())
#plt.xlabel('Tiempo', fontsize=20)
#plt.ylabel('Corriente (mA)', fontsize=20)
#plt.plot(tiempo,corriente)

# %%
#Separamos todos los voltajes
voltaje1 = voltaje[1:30:1]
voltaje2 = voltaje[32:60:1]
voltaje3 = voltaje[62:90:1]
voltaje4 = voltaje[92:120:1]
voltaje5 = voltaje[122:150:1]
voltaje6 = voltaje[152:180:1]
voltaje7 = voltaje[182:210:1]
voltaje8 = voltaje[212:240:1]
voltaje9 = voltaje[242:270:1]
voltaje10 = voltaje[272:300:1]
voltaje11 = voltaje[302:330:1]
voltaje12 = voltaje[332:360:1]

#Separamos todas las corrientes
corriente1 = corriente[1:30:1]
corriente2 = corriente[32:60:1]
corriente3 = corriente[62:90:1]
corriente4 = corriente[92:120:1]
corriente5 = corriente[122:150:1]
corriente6 = corriente[152:180:1]
corriente7 = corriente[182:210:1]
corriente8 = corriente[212:240:1]
corriente9 = corriente[242:270:1]
corriente10 = corriente[272:300:1]
corriente11 = corriente[302:330:1]
corriente12 = corriente[332:360:1]

#Grafica tiempo
corriente13 = corriente[332:400:1]
tiempo12 = tiempo[332:400:1]
desvcorr13 = np.std(corriente13)
corrientemed13 = np.mean(corriente13)
print(len(corriente13))
print(len(tiempo12))
print(desvcorr13)
print(corrientemed13)
# Out:
# 68
# 68
# 0.014319293672533812
# 36.23845588235294

# %%
#valores medios y deviaciones estandar
#voltaje
voltajemed1 = np.mean(voltaje1)
voltajemed2 = np.mean(voltaje2)
voltajemed3 = np.mean(voltaje3)
voltajemed4 = np.mean(voltaje4)
voltajemed5 = np.mean(voltaje5)
voltajemed6 = np.mean(voltaje6)
voltajemed7 = np.mean(voltaje7)
voltajemed8 = np.mean(voltaje8)
voltajemed9 = np.mean(voltaje9)
voltajemed10 = np.mean(voltaje10)
voltajemed11 = np.mean(voltaje11)
voltajemed12 = np.mean(voltaje12)

#Corrientes
corrientemed1 = np.mean(corriente1)
corrientemed2 = np.mean(corriente2)
corrientemed3 = np.mean(corriente3)
corrientemed4 = np.mean(corriente4)
corrientemed5 = np.mean(corriente5)
corrientemed6 = np.mean(corriente6)
corrientemed7 = np.mean(corriente7)
corrientemed8 = np.mean(corriente8)
corrientemed9 = np.mean(corriente9)
corrientemed10 = np.mean(corriente10)
corrientemed11 = np.mean(corriente11)
corrientemed12 = np.mean(corriente12)

#Desvi Corrientes
desvcorr1 = np.std(corriente1)
desvcorr2 = np.std(corriente2)
desvcorr3 = np.std(corriente3)
desvcorr4 = np.std(corriente4)
desvcorr5 = np.std(corriente5)
desvcorr6 = np.std(corriente6)
desvcorr7 = np.std(corriente7)
desvcorr8 = np.std(corriente8)
desvcorr9 = np.std(corriente9)
desvcorr10 = np.std(corriente10)
desvcorr11 = np.std(corriente11)
desvcorr12 = np.std(corriente12)
print(desvcorr12)
#Desvi Voltajes
desvoltaje1 = np.std(voltaje1)
desvoltaje2 = np.std(voltaje2)
desvoltaje3 = np.std(voltaje3)
desvoltaje4 = np.std(voltaje4)
desvoltaje5 = np.std(voltaje5)
desvoltaje6 = np.std(voltaje6)
desvoltaje7 = np.std(voltaje7)
desvoltaje8 = np.std(voltaje8)
desvoltaje9 = np.std(voltaje9)
desvoltaje10 = np.std(voltaje10)
desvoltaje11 = np.std(voltaje11)
desvoltaje12 = np.std(voltaje12)
print("Dev1",desvoltaje1)
# Out:
# 0.014698457159073398
# Dev1 8.160110045654581e-07

# %%
#arreglos
voltajes = np.array([voltajemed1, voltajemed2, voltajemed3, voltajemed4, voltajemed5, voltajemed6, voltajemed7, voltajemed8, voltajemed9, voltajemed10, voltajemed11, voltajemed12])
corrientes = np.array([corrientemed1, corrientemed2, corrientemed3, corrientemed4, corrientemed5, corrientemed6, corrientemed7, corrientemed8, corrientemed9, corrientemed10, corrientemed11, corrientemed12])
desvcorrientes = np.array([desvcorr1, desvcorr2, desvcorr3, desvcorr4, desvcorr5, desvcorr6, desvcorr7, desvcorr8, desvcorr9, desvcorr10, desvcorr11, desvcorr12])
desvoltajes = np.array([desvoltaje1, desvoltaje2, desvoltaje3, desvoltaje4, desvoltaje5, desvoltaje6, desvoltaje7, desvoltaje8, desvoltaje9, desvoltaje10, desvoltaje11, desvoltaje12])
#np.set_printoptions(precision=5)
np.set_printoptions(suppress=True)
print(voltajes)
print(corrientes)
print(desvcorrientes)
print(desvoltajes)
# Out:
# [0.00013724 0.42093668 0.83940021 1.25696036 1.6753275  2.09402214
#  2.51287857 2.92670036 3.33724643 3.75282286 4.16794107 4.35445214]
# [ 0.          0.          7.12928571 10.57460714 14.03660714 17.50303571
#  20.97510714 24.40053571 27.75314286 31.23635714 34.68789286 36.23825   ]
# [0.         0.         0.01463327 0.01425367 0.01414299 0.01254843
#  0.01813706 0.02075449 0.01593001 0.01901919 0.02294145 0.01469846]
# [0.00000082 0.0001743  0.00029906 0.00049736 0.00066967 0.00084261
#  0.00101406 0.00122257 0.0010882  0.00156501 0.00174787 0.00010998]

# %%
xvals = voltajes
def ajuste(xvals):
    "Curva de ajuste con la forma y = mx+b"
    yvals = (8.3*xvals) + (0.1019)
    return yvals
yvals = ajuste(xvals)

# %%
plt.figure(figsize=(20,10))
#Ploteo de datos
plt.errorbar(voltajes, corrientes, yerr=desvcorrientes, label="Corriente vs. Voltaje",linestyle='dashed', marker = "+")
plt.plot(xvals,yvals, label="y = 8.3x - 0.1019", color='red',linestyle='dashed',linewidth=.5)
#Configuracion
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Voltaje (V)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)

plt.title('Corriente vs. Voltaje (Rama Corriente Umbral Controlador 780nm)', fontsize=20)
# Leyendas
plt.legend(loc='upper left', prop={'size': 15})
#Texto
plt.text(0.1,0.2,'177.21 $\mu$ V - 0.258mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
#plt.text(0.5,3.9,'420.809mV  - 3.934mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.88,7.1,'839.134mV  - 7.601mA $\pm$ 0.001mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.31,10.57,'1.257V  - 11.266mA $\pm$ 0.002mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.73,14.0,'1.675V  - 14.940mA $\pm$ 0.002mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.16,17.5,'2.094V  - 18.619mA $\pm$ 0.004mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.58,20.97,'2.514V  - 22.301mA $\pm$ 0.004mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.98,24.4,'2.928V  - 25.944mA $\pm$ 0.006mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,27.7,'3.343V  - 29.592mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.8,31.3,'3.759V  - 33.253mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.2,34.68,'4.172V  - 36.893mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,36.23,'4.355V  - 38.491mA $\pm$ 0.001mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
#plt.savefig('Graphs/Controlador780.jpg')
plt.savefig('Graphs/Controlador780.png')
plt.show()

# %%
plt.figure(figsize=(20,10))
axes = plt.axes()
axes.set_xticklabels(tiempo,rotation = 90)
axes.xaxis.set_tick_params(labelsize = 14)
axes.yaxis.set_tick_params(labelsize = 14)
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
#plt.ylim(35.2,37.2)
plt.title('Grafica de estabilidad Corriente vs. Tiempo 780nm', fontsize=20)
plt.xlabel('Tiempo', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.plot(tiempo12,corriente13, label='Corriente',marker='+')
corrprom = np.full((len(corriente13)),corrientemed13)
plt.errorbar(tiempo12, corrprom, yerr=desvcorr13 ,label='Corriente Promedio', linestyle='dashed',marker='o')
plt.legend(prop={'size': 15})
#plt.savefig('Graphs/CorrienteTiempo780.jpg')
plt.savefig('Graphs/CorrienteTiempo780.png')
plt.show()

# %% [markdown]
# # 2das Mediciones

# %%
dataframe2=pd.read_csv('Files/7800511.csv')
tiempoo = dataframe2['Tiempo']
corrientee = dataframe2['Corriente']
voltajee = dataframe2['Voltaje']
corrientee = corrientee.to_numpy()
voltajee = voltajee.to_numpy()

# %%
#Valor de corriente en mA legibles
corrientee = corrientee*1000

# %%
#Separamos todos los voltajes
voltaje14 = voltajee[1:30:1]
voltaje15 = voltajee[32:60:1]
voltaje16 = voltajee[62:90:1]
voltaje17 = voltajee[92:120:1]
voltaje18 = voltajee[122:150:1]
voltaje19 = voltajee[152:180:1]
voltaje20 = voltajee[182:210:1]
voltaje21 = voltajee[212:240:1]
voltaje22 = voltajee[242:270:1]
voltaje23 = voltajee[272:300:1]
voltaje24 = voltajee[302:330:1]
voltaje25 = voltajee[332:360:1]

#Separamos todas las corrientes
corriente14 = corrientee[1:30:1]
corriente15 = corrientee[32:60:1]
corriente16 = corrientee[62:90:1]
corriente17 = corrientee[92:120:1]
corriente18 = corrientee[122:150:1]
corriente19 = corrientee[152:180:1]
corriente20 = corrientee[182:210:1]
corriente21 = corrientee[212:240:1]
corriente22 = corrientee[242:270:1]
corriente23 = corrientee[272:300:1]
corriente24 = corrientee[302:330:1]
corriente25 = corrientee[332:360:1]

# %%
print(len(corriente25))

#Grafica tiempo
corriente26 = corrientee[332:400:1]
tiempo13 = tiempoo[332:400:1]
desvcorr26 = np.std(corriente26)
corrientemed26 = np.mean(corriente26)
print(len(corriente26))
print(len(tiempo13))
print(desvcorr26)
print(corrientemed26)
# Out:
# 28
# 68
# 68
# 0.015952161398607296
# 36.21338235294119

# %%
#valores medios y deviaciones estandar
#voltaje
voltajemed14 = np.mean(voltaje14)
voltajemed15 = np.mean(voltaje15)
voltajemed16 = np.mean(voltaje16)
voltajemed17 = np.mean(voltaje17)
voltajemed18 = np.mean(voltaje18)
voltajemed19 = np.mean(voltaje19)
voltajemed20 = np.mean(voltaje20)
voltajemed21 = np.mean(voltaje21)
voltajemed22 = np.mean(voltaje22)
voltajemed23 = np.mean(voltaje23)
voltajemed24 = np.mean(voltaje24)
voltajemed25 = np.mean(voltaje25)

#Corrientes
corrientemed14 = np.mean(corriente14)
corrientemed15 = np.mean(corriente15)
corrientemed16 = np.mean(corriente16)
corrientemed17 = np.mean(corriente17)
corrientemed18 = np.mean(corriente18)
corrientemed19 = np.mean(corriente19)
corrientemed20 = np.mean(corriente20)
corrientemed21 = np.mean(corriente21)
corrientemed22 = np.mean(corriente22)
corrientemed23 = np.mean(corriente23)
corrientemed24 = np.mean(corriente24)
corrientemed25 = np.mean(corriente25)

#Desvi Corrientes
desvcorr14 = np.std(corriente14)
desvcorr15 = np.std(corriente15)
desvcorr16 = np.std(corriente16)
desvcorr17 = np.std(corriente17)
desvcorr18 = np.std(corriente18)
desvcorr19 = np.std(corriente19)
desvcorr20 = np.std(corriente20)
desvcorr21 = np.std(corriente21)
desvcorr22 = np.std(corriente22)
desvcorr23 = np.std(corriente23)
desvcorr24 = np.std(corriente24)
desvcorr25 = np.std(corriente25)

#Desvi Voltajes
desvoltaje14 = np.std(voltaje14)
desvoltaje15 = np.std(voltaje15)
desvoltaje16 = np.std(voltaje16)
desvoltaje17 = np.std(voltaje17)
desvoltaje18 = np.std(voltaje18)
desvoltaje19 = np.std(voltaje19)
desvoltaje20 = np.std(voltaje20)
desvoltaje21 = np.std(voltaje21)
desvoltaje22 = np.std(voltaje22)
desvoltaje23 = np.std(voltaje23)
desvoltaje24 = np.std(voltaje24)
desvoltaje25 = np.std(voltaje25)
print("Dev1",desvoltaje14)
# Out:
# Dev1 2.533954906327418e-07

# %%
#arreglos
voltajes2 = np.array([voltajemed14, voltajemed15, voltajemed16, voltajemed17, voltajemed18, voltajemed19, voltajemed20, voltajemed21, voltajemed22, voltajemed23, voltajemed24, voltajemed25])
corrientes2 = np.array([corrientemed14, corrientemed15, corrientemed16, corrientemed17, corrientemed18, corrientemed19, corrientemed20, corrientemed21, corrientemed22, corrientemed23, corrientemed24, corrientemed25])
desvcorrientes2 = np.array([desvcorr14, desvcorr15, desvcorr16, desvcorr17, desvcorr18, desvcorr19, desvcorr20, desvcorr21, desvcorr22, desvcorr23, desvcorr24, desvcorr25])
desvoltajes2 = np.array([desvoltaje14, desvoltaje15, desvoltaje16, desvoltaje17, desvoltaje18, desvoltaje19, desvoltaje20, desvoltaje21, desvoltaje22, desvoltaje23, desvoltaje24, desvoltaje25])

np.set_printoptions(suppress=True)
print('Voltajes: ', voltajes2)
print('Corrientes: ', corrientes2)
print('Desv Corrientes: ', desvcorrientes2)
print('Desv Voltajes: ', desvoltajes2)
# Out:
# Voltajes:  [0.00012607 0.42117946 0.84041139 1.25866143 1.67745429 2.0963575
#  2.51559607 2.92873964 3.34292857 3.75588607 4.17182607 4.35177679]
# Corrientes:  [ 0.          0.          7.13203571 10.59117857 14.05292857 17.52046429
#  20.99235714 24.41085714 27.83767857 31.25439286 34.71871429 36.21457143]
# Desv Corrientes:  [0.         0.         0.013292   0.01315309 0.02007829 0.01805049
#  0.01324552 0.01615265 0.01953761 0.02107697 0.02054239 0.01555044]
# Desv Voltajes:  [0.00000025 0.0001948  0.00038656 0.00051589 0.00073178 0.00096024
#  0.00105776 0.00125637 0.00149917 0.00169562 0.00175223 0.00011174]

# %%
#Funcion de regresion
xvals = voltajes2
def ajuste(xvals):
    "Curva de ajuste con la forma y = mx+b"
    yvals = (8.3*xvals) + (0.1019)
    return yvals
yvals = ajuste(xvals)

# %%
plt.figure(figsize=(20,10))
#Ploteo de datos
plt.errorbar(voltajes2, corrientes2, yerr=desvcorrientes2, label="Corriente vs. Voltaje",linestyle='dashed', marker = "+")
plt.plot(xvals,yvals, label="y = 8.3x - 0.1019", color='red',linestyle='dashed',linewidth=.5)
#Configuracion
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Voltaje (V)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)

plt.title('Corriente vs. Voltaje (Rama Corriente Umbral Controlador 780nm)', fontsize=20)
# Leyendas
plt.legend(loc='upper left',prop={'size': 15})
#Texto
plt.text(0.1,0.2,'177.21 $\mu$ V - 0.258mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
#plt.text(0.5,3.9,'420.809mV  - 3.934mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.88,7.1,'839.134mV  - 7.601mA $\pm$ 0.001mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.31,10.57,'1.257V  - 11.266mA $\pm$ 0.002mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.73,14.0,'1.675V  - 14.940mA $\pm$ 0.002mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.16,17.5,'2.094V  - 18.619mA $\pm$ 0.004mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.58,20.97,'2.514V  - 22.301mA $\pm$ 0.004mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.98,24.4,'2.928V  - 25.944mA $\pm$ 0.006mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,27.7,'3.343V  - 29.592mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.8,31.3,'3.759V  - 33.253mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.2,34.68,'4.172V  - 36.893mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,36.23,'4.355V  - 38.491mA $\pm$ 0.001mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.savefig('Graphs/Controlador780-2.jpg')
plt.savefig('Graphs/Controlador780-2.png')
plt.show()

# %%
plt.figure(figsize=(20,10))
axes = plt.axes()
axes.set_xticklabels(tiempo,rotation = 90)
axes.xaxis.set_tick_params(labelsize = 14)
axes.yaxis.set_tick_params(labelsize = 14)
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
#plt.ylim(67,68)
plt.title('Grafica de estabilidad Corriente vs. Tiempo 780nm', fontsize=20)
plt.xlabel('Tiempo', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.plot(tiempo13,corriente26, label='Corriente',marker='+')
corrprom26 = np.full((len(corriente26)),corrientemed26)
plt.errorbar(tiempo13,corrprom26, yerr=desvcorr26 ,label='Corriente Promedio', linestyle='dashed',marker='o')
plt.legend(prop={'size': 15})
plt.savefig('Graphs/CorrienteTiempo780-2.jpg')
plt.savefig('Graphs/CorrienteTiempo780-2.png')
plt.show()

# %% [markdown]
# # 3ras Mediciones

# %%
dataframe3=pd.read_csv('Files/78005112.csv')
tiempooo = dataframe3['Tiempo']
corrienteee = dataframe3['Corriente']
voltajeee = dataframe3['Voltaje']
corrienteee = corrienteee.to_numpy()
voltajeee = voltajeee.to_numpy()

# %%
#Valor de corriente en mA legibles
corrienteee = corrienteee * 1000

# %%
#Separamos todos los voltajes
voltaje27 = voltajeee[1:30:1]
voltaje28 = voltajeee[32:60:1]
voltaje29 = voltajeee[62:90:1]
voltaje30 = voltajeee[92:120:1]
voltaje31 = voltajeee[122:150:1]
voltaje32 = voltajeee[152:180:1]
voltaje33 = voltajeee[182:210:1]
voltaje34 = voltajeee[212:240:1]
voltaje35 = voltajeee[242:270:1]
voltaje36 = voltajeee[272:300:1]
voltaje37 = voltajeee[302:330:1]
voltaje38 = voltajeee[332:360:1]

# %%
#Separamos todas las corrientes
corriente27 = corrienteee[1:30:1]
corriente28 = corrienteee[32:60:1]
corriente29 = corrienteee[62:90:1]
corriente30 = corrienteee[92:120:1]
corriente31 = corrienteee[122:150:1]
corriente32 = corrienteee[152:180:1]
corriente33 = corrienteee[182:210:1]
corriente34 = corrienteee[212:240:1]
corriente35 = corrienteee[242:270:1]
corriente36 = corrienteee[272:300:1]
corriente37 = corrienteee[302:330:1]
corriente38 = corrienteee[332:360:1]

#Grafica tiempo
corriente39 = corrienteee[332:400:1]
tiempo14 = tiempooo[332:400:1]
desvcorr39 = np.std(corriente39)
corrientemed39 = np.mean(corriente39)
print(len(corriente39))
print(len(tiempo14))
print(desvcorr39)
print(corrientemed39)
# Out:
# 68
# 68
# 0.013536914479792966
# 36.243544117647055

# %%
#valores medios y deviaciones estandar
#voltaje
voltajemed27 = np.mean(voltaje27)
voltajemed28 = np.mean(voltaje28)
voltajemed29 = np.mean(voltaje29)
voltajemed30 = np.mean(voltaje30)
voltajemed31 = np.mean(voltaje31)
voltajemed32 = np.mean(voltaje32)
voltajemed33 = np.mean(voltaje33)
voltajemed34 = np.mean(voltaje34)
voltajemed35 = np.mean(voltaje35)
voltajemed36 = np.mean(voltaje36)
voltajemed37 = np.mean(voltaje37)
voltajemed38 = np.mean(voltaje38)

#Corrientes
corrientemed27 = np.mean(corriente27)
corrientemed28 = np.mean(corriente28)
corrientemed29 = np.mean(corriente29)
corrientemed30 = np.mean(corriente30)
corrientemed31 = np.mean(corriente31)
corrientemed32 = np.mean(corriente32)
corrientemed33 = np.mean(corriente33)
corrientemed34 = np.mean(corriente34)
corrientemed35 = np.mean(corriente35)
corrientemed36 = np.mean(corriente36)
corrientemed37 = np.mean(corriente37)
corrientemed38 = np.mean(corriente38)

#Desvi Corrientes
desvcorr27 = np.std(corriente27)
desvcorr28 = np.std(corriente28)
desvcorr29 = np.std(corriente29)
desvcorr30 = np.std(corriente30)
desvcorr31 = np.std(corriente31)
desvcorr32 = np.std(corriente32)
desvcorr33 = np.std(corriente33)
desvcorr34 = np.std(corriente34)
desvcorr35 = np.std(corriente35)
desvcorr36 = np.std(corriente36)
desvcorr37 = np.std(corriente37)
desvcorr38 = np.std(corriente38)

#Desvi Voltajes
desvoltaje27 = np.std(voltaje27)
desvoltaje28 = np.std(voltaje28)
desvoltaje29 = np.std(voltaje29)
desvoltaje30 = np.std(voltaje30)
desvoltaje31 = np.std(voltaje31)
desvoltaje32 = np.std(voltaje32)
desvoltaje33 = np.std(voltaje33)
desvoltaje34 = np.std(voltaje34)
desvoltaje35 = np.std(voltaje35)
desvoltaje36 = np.std(voltaje36)
desvoltaje37 = np.std(voltaje37)
desvoltaje38 = np.std(voltaje38)
print("Dev1",desvoltaje27)
# Out:
# Dev1 8.668831096535517e-07

# %%
#arreglos
voltajes3 = np.array([voltajemed27, voltajemed28, voltajemed29, voltajemed30, voltajemed31, voltajemed32, voltajemed33, voltajemed34, voltajemed35, voltajemed36, voltajemed37, voltajemed38])
corrientes3 = np.array([corrientemed27, corrientemed28, corrientemed29, corrientemed30, corrientemed31, corrientemed32, corrientemed33, corrientemed34, corrientemed35, corrientemed36, corrientemed37, corrientemed38])
desvcorrientes3 = np.array([desvcorr27, desvcorr28, desvcorr29, desvcorr30, desvcorr31, desvcorr32, desvcorr33, desvcorr34, desvcorr35, desvcorr36, desvcorr37, desvcorr38])
desvoltajes3 = np.array([desvoltaje27, desvoltaje28, desvoltaje29, desvoltaje30, desvoltaje31, desvoltaje32, desvoltaje33, desvoltaje34, desvoltaje35, desvoltaje36, desvoltaje37, desvoltaje38])

np.set_printoptions(suppress=True)
print('Voltajes: ', voltajes3)
print('Corrientes: ', corrientes3)
print('Desv Corrientes: ', desvcorrientes3)
print('Desv Voltajes: ', desvoltajes3)
# Out:
# Voltajes:  [0.00013928 0.42122579 0.84060264 1.2585925  1.67715    2.09632321
#  2.51553143 2.929085   3.34271786 3.75491321 4.17139036 4.35202214]
# Corrientes:  [ 0.          0.          7.15932143 10.62260714 14.08107143 17.54960714
#  21.0235     24.44760714 27.85664286 31.27153571 34.74310714 36.24396429]
# Desv Corrientes:  [0.         0.         0.01408914 0.01616729 0.0133949  0.01621362
#  0.01830788 0.01744653 0.01778485 0.02029863 0.02012699 0.01281874]
# Desv Voltajes:  [0.00000087 0.00016627 0.00043648 0.00054619 0.00072719 0.00096497
#  0.00108439 0.00128338 0.001498   0.00175088 0.00188032 0.00016874]

# %%
#Funcion de regresion
xvals = voltajes2
def ajuste(xvals):
    "Curva de ajuste con la forma y = mx+b"
    yvals = (8.3*xvals) + (0.1019)
    return yvals
yvals = ajuste(xvals)

# %%
plt.figure(figsize=(20,10))
#Ploteo de datos
plt.errorbar(voltajes2, corrientes2, yerr=desvcorrientes2, label="Corriente vs. Voltaje",linestyle='dashed', marker = "+")
plt.plot(xvals,yvals, label="y = 8.3x - 0.1019", color='red',linestyle='dashed',linewidth=.5)
#Configuracion
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Voltaje (V)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)

plt.title('Corriente vs. Voltaje (Rama Corriente Umbral Controlador 780nm)', fontsize=20)
# Leyendas
plt.legend(loc='upper left',prop={'size': 15})
#Texto
plt.text(0.1,0.2,'177.21 $\mu$ V - 0.258mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
#plt.text(0.5,3.9,'420.809mV  - 3.934mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.88,7.1,'839.134mV  - 7.601mA $\pm$ 0.001mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.31,10.57,'1.257V  - 11.266mA $\pm$ 0.002mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.73,14.0,'1.675V  - 14.940mA $\pm$ 0.002mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.16,17.5,'2.094V  - 18.619mA $\pm$ 0.004mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.58,20.97,'2.514V  - 22.301mA $\pm$ 0.004mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.98,24.4,'2.928V  - 25.944mA $\pm$ 0.006mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,27.7,'3.343V  - 29.592mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.8,31.3,'3.759V  - 33.253mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.2,34.68,'4.172V  - 36.893mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,36.23,'4.355V  - 38.491mA $\pm$ 0.001mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.savefig('Graphs/Controlador780-3.jpg')
plt.savefig('Graphs/Controlador780-3.png')
plt.show()

# %%
plt.figure(figsize=(20,10))
axes = plt.axes()
axes.set_xticklabels(tiempo,rotation = 90)
axes.xaxis.set_tick_params(labelsize = 14)
axes.yaxis.set_tick_params(labelsize = 14)
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
#plt.ylim(67,68)
plt.title('Grafica de estabilidad Corriente vs. Tiempo 780nm', fontsize=20)
plt.xlabel('Tiempo', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.plot(tiempo14,corriente39, label='Corriente',marker='+')
corrprom39 = np.full((len(corriente39)),corrientemed39)
plt.errorbar(tiempo14,corrprom39, yerr=desvcorr39 ,label='Corriente Promedio', linestyle='dashed',marker='o')
plt.legend(prop={'size': 15})
plt.savefig('Graphs/CorrienteTiempo780-3.jpg')
plt.savefig('Graphs/CorrienteTiempo780-3.png')
plt.show()

# %% [markdown]
# # Calculo Final
# Combinacion de todos los datos para sacar el comportamiento del driver.
# Se obtienen los valores de corriente promedio en todos los puntos se hacen 3 mediciones en 3 distintos tiempos, 30 mediciones por punto.
# Y se calculan con la formula de media ponderada.

# %%
voltajesf = ((voltajes/desvoltajes**2) + (voltajes2/desvoltajes2**2)+(voltajes3/desvoltajes3**2))/((1/desvoltajes**2)+(1/desvoltajes2**2)+(1/desvoltajes3**2))
corrientesf = ((corrientes/desvcorrientes**2) + (corrientes2/desvcorrientes2**2) + (corrientes3/desvcorrientes3**2))/((1/desvcorrientes**2)+(1/desvcorrientes2**2)+(1/desvcorrientes3**2))
desvcorrientesf = 1/(np.sqrt((1/desvcorrientes**2)+(1/desvcorrientes2**2)+(1/desvcorrientes3**2)))
#voltajef = np.mean(voltajef)
print(voltajesf)
corrientesf[0] = 0
corrientesf[1] = 0
print(corrientesf)
print(desvcorrientesf)
# Out:
# [0.00012794 0.42111329 0.83996585 1.25802408 1.67656624 2.09542501
#  2.51460306 2.92813501 3.34010887 3.75443729 4.17033558 4.35293809]
# [ 0.          0.          7.14014455 10.59384064 14.05869371 17.52047758
#  20.99580969 24.42110911 27.80958033 31.25328379 34.7189597  36.23399778]
# [0.         0.         0.00806669 0.00829651 0.00875264 0.00869602
#  0.00923583 0.01029252 0.010142   0.01159151 0.01218218 0.00820618]
# C:\Users\MCDav\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\MCDav\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\MCDav\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Funcion de regresion
xvals = voltajes2
def ajuste(xvals):
    "Curva de ajuste con la forma y = mx+b"
    yvals = (8.3*xvals) + (0.1019)
    return yvals
yvals = ajuste(xvals)

# %%
plt.figure(figsize=(20,10))
#Ploteo de datos
plt.errorbar(voltajesf, corrientesf, yerr=desvcorrientesf, label="Corriente vs. Voltaje",linestyle='dashed', marker = "+")
plt.plot(xvals,yvals, label="y = 8.3x - 0.1019", color='red',linestyle='dashed',linewidth=.5)
#Configuracion
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Voltaje (V)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)

plt.title('Corriente vs. Voltaje (Rama Corriente Umbral Controlador 780nm)', fontsize=20)
# Leyendas
plt.legend(loc='upper left',prop={'size': 15})
#Texto
plt.text(0.1,0.2,'127.94 $\mu$ V - 0.000mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.5,3.9,'421.132mV  - 0.000mA $\pm$ 0.000mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.88,7.1,'839.965mV  - 7.140mA $\pm$ 0.008mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.31,10.57,'1.258V  - 10.593mA $\pm$ 0.008mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.73,14.0,'1.676V  - 14.058mA $\pm$ 0.008mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.16,17.5,'2.095V  - 17.520mA $\pm$ 0.008mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.58,20.97,'2.514V  - 20.995mA $\pm$ 0.009mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.98,24.4,'2.928V  - 24.421mA $\pm$ 0.010mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,27.7,'3.340V  - 27.809mA $\pm$ 0.010mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.8,31.3,'3.754V  - 31.253mA $\pm$ 0.011mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.2,34.68,'4.170V  - 34.718mA $\pm$ 0.012mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.4,36.23,'4.352V  - 36.233mA $\pm$ 0.008mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.savefig('Graphs/Controlador780-f.jpg')
plt.savefig('Graphs/Controlador780-f.png')
plt.show()

# %%
corrienteprom13 = np.mean(corriente13)
corrienteprom26 = np.mean(corriente26)
corrienteprom39 = np.mean(corriente39)
corrientepromf = ((corrienteprom13/desvcorr13**2)+(corrienteprom26/desvcorr26**2)+(corrienteprom39/desvcorr39**2))/((1/desvcorr13**2)+(1/desvcorr26**2)+(1/desvcorr39**2))
desvcorrf = 1/np.sqrt((1/desvcorr13**2)+(1/desvcorr26**2)+(1/desvcorr39**2))
print(corrientepromf)
print(desvcorrf)
tiempograph = np.arange(2, 138, 2)
print(len(corriente13))
print(len(tiempograph))
# Out:
# 36.23349474612613
# 0.008373012142929261
# 68
# 68

# %%
plt.figure(figsize=(20,10))
axes = plt.axes()
#axes.set_xticklabels(tiempograph,rotation = 90)
axes.xaxis.set_tick_params(labelsize = 14)
axes.yaxis.set_tick_params(labelsize = 14)
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.ylim(36.13,36.33)
plt.title('Grafica de estabilidad Corriente vs. Tiempo 780nm', fontsize=20)
plt.xlabel('Tiempo (s)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.plot(tiempograph,corriente13, 'yo',label='Corriente 1')
plt.plot(tiempograph,corriente26, 'ro',label='Corriente 2')
plt.plot(tiempograph,corriente39, 'go',label='Corriente 3')
corrprom13 = np.full((len(corriente13)),corrientepromf)
plt.errorbar(tiempograph, corrprom13, yerr=desvcorrf ,label='Corriente Promedio 36.233mA $\pm$ 0.008mA',uplims=True, lolims=True,)
plt.legend(prop={'size': 15})
plt.savefig('Graphs/CorrienteTiempo780-f.jpg')
plt.savefig('Graphs/CorrienteTiempo780-f.png')
plt.show()
#print(tiempograph)
