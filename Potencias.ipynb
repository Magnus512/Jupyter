# %%
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from datetime import datetime
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
dataframe1=pd.read_csv('Files/Potencia660.csv')
dataframe2=pd.read_csv('Files/Potencia780.csv')
dataframe3=pd.read_csv('Files/Potencia808.csv')
dataframe4=pd.read_csv('Files/Potencia850.csv')

# %%
corriente660 = dataframe1['Corriente']
potencia660 = dataframe1['Potencia']
print(corriente660)
# Out:
# 0       2.5000
# 1       7.0030
# 2      14.1220
# 3      28.1185
# 4      35.1145
# 5      42.1725
# 6      49.1465
# 7      63.2100
# 8      84.2400
# 9     105.2900
# 10    126.3400
# 11    147.0900
# 12    167.9850
# 13    188.8350
# Name: Corriente, dtype: float64

# %%
x = np.linspace(0,250,500)
def curva1(x):
    y1 = -0.1014285714+0.004285714286*x
    return y1 

def curva2(x):
    y2 = -31.5107604+0.8020086083*x
    return y2

y1 = curva1(x)
y2 = curva2(x)
print(len(y2))
print(len(x))
# Out:
# 500
# 500

# %%
plt.figure(figsize=(15,10))
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Corriente (mA)', fontsize=20)
plt.ylabel('Potencia (mW)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)
plt.ylim(0,90)
plt.xlim(0,190)

plt.title('Potencia vs. Corriente 660nm', fontsize=20)

plt.plot(x,y1, label = "y = -0.101+0.004*x")
plt.plot(x,y2, label = "y = -31.510+0.802*x")
plt.plot(corriente660,potencia660, label = "Potencia vs. Corriente")
plt.legend(prop={'size': 12})
plt.savefig('Graphs/PC660-f.jpg')
plt.show()

#Corriente Umbral
a = np.array([[-0.004285714286, 1],[-0.8020086083,1]])
b = np.array([-0.1014285714, -31.5107604])

print(np.linalg.solve(a,b))
# Out:
# [39.3737375   0.06731602]

# %%
corriente780 = dataframe2['Corriente']
potencia780 = dataframe2['Potencia']

# %%
x = np.linspace(0,250,250)
def curva1(x):
    y1 = -0.02725968436+(2/697)*x
    return y1 

def curva2(x):
    y2 = -29.10903874+0.8120516499*x
    return y2

y1 = curva1(x)
y2 = curva2(x)
print(len(y2))
print(len(x))
# Out:
# 250
# 250

# %%
plt.figure(figsize=(15,10))
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Corriente (mA)', fontsize=20)
plt.ylabel('Potencia (mW)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)
plt.ylim(0,80)
plt.xlim(0,170)


plt.title('Potencia vs. Corriente 780nm', fontsize=20)

plt.plot(x,y1, label = "y = -0.027+(2/697)*x")
plt.plot(x,y2, label = "y = -29.109+0.812*x")
plt.plot(corriente780,potencia780, label = "Potencia vs. Corriente")
plt.legend(prop={'size': 12})
plt.savefig('Graphs/PC780-f.jpg')
plt.show()

#Corriente Umbral
a = np.array([[-(2/697), 1],[-0.8120516499,1]])
b = np.array([-0.02725968436, -29.10903874])

print(np.linalg.solve(a,b))
# Out:
# [35.93971632  0.07586719]

# %%
corriente808 = dataframe3['Corriente']
potencia808 = dataframe3['Potencia']

# %%
x = np.linspace(0,250,250)
def curva1(x):
    y1 = -1.11+0.02428571429*x
    return y1 

def curva2(x):
    y2 = -30.56552707+0.4643874644*x
    return y2

y1 = curva1(x)
y2 = curva2(x)
print(len(y2))
print(len(x))
# Out:
# 250
# 250

# %%
plt.figure(figsize=(15,10))
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Corriente (mA)', fontsize=20)
plt.ylabel('Potencia (mW)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)
plt.ylim(0,65)
plt.xlim(0,215)

plt.title('Potencia vs. Corriente 808nm', fontsize=20)

plt.plot(x,y1, label = "y = -1.11+0.024*x")
plt.plot(x,y2, label = "y = -30.565+0.464*x")
plt.plot(corriente808,potencia808)

plt.legend(prop={'size': 12})
plt.savefig('Graphs/PC808-f.jpg')
plt.show()

#Corriente Umbral
a = np.array([[-0.02428571429, 1],[-0.4643874644,1]])
b = np.array([-1.11, -30.56552707])

print(np.linalg.solve(a,b))
# Out:
# [66.92890238  0.5154162 ]

# %%
corriente850 = dataframe4['Corriente']
potencia850 = dataframe4['Potencia']

# %%
x = np.linspace(0,360,360)
def curva1(x):
    y1 = -1.73+0.03*x
    return y1 

def curva2(x):
    y2 = -266.7+1.09*x
    return y2

y1 = curva1(x)
y2 = curva2(x)
print(len(y2))
print(len(x))
# Out:
# 360
# 360

# %%
plt.figure(figsize=(15,10))
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Corriente (mA)', fontsize=20)
plt.ylabel('Potencia (mW)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)
plt.ylim(0,72)
plt.xlim(0,360)

plt.title('Potencia vs. Corriente 850nm', fontsize=20)

plt.plot(x,y1, label = "y = -1.73+0.03*x")
plt.plot(x,y2, label = "y = -266.7+1.09*x")
plt.plot(corriente850,potencia850)

plt.legend(prop={'size': 12})
plt.savefig('Graphs/PC850-f.jpg')
plt.show()

#Corriente Umbral
a = np.array([[-0.03, 1],[-1.09,1]])
b = np.array([-1.73, -266.7])

print(np.linalg.solve(a,b))
# Out:
# [249.97169811   5.76915094]
