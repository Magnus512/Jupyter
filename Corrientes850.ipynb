# %%
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import scipy

# %%
dataframe=pd.read_csv('Files/850nuevo.csv')

# %%
#print(dataframe)

tiempo = dataframe['Tiempo']
corriente = dataframe['Corriente']
voltaje = dataframe['Voltaje']

corriente = corriente*1000

# %%
#Separamos todos los voltajes
voltaje1 = voltaje[1:30:1]
voltaje2 = voltaje[32:60:1]
voltaje3 = voltaje[62:90:1]
voltaje4 = voltaje[92:120:1]
voltaje5 = voltaje[122:150:1]
voltaje6 = voltaje[152:180:1]
voltaje7 = voltaje[182:210:1]
voltaje8 = voltaje[212:240:1]
voltaje9 = voltaje[242:270:1]
voltaje10 = voltaje[272:300:1]
voltaje11 = voltaje[302:330:1]
voltaje12 = voltaje[332:360:1]
voltaje13 = voltaje[361:390:1]
voltaje14 = voltaje[391:420:1]

#Separamos todas las corrientes
corriente1 = corriente[1:30:1]
corriente2 = corriente[32:60:1]
corriente3 = corriente[62:90:1]
corriente4 = corriente[92:120:1]
corriente5 = corriente[122:150:1]
corriente6 = corriente[152:180:1]
corriente7 = corriente[182:210:1]
corriente8 = corriente[212:240:1]
corriente9 = corriente[242:270:1]
corriente10 = corriente[272:300:1]
corriente11 = corriente[302:330:1]
corriente12 = corriente[332:360:1]
corriente13 = corriente[361:390:1]
corriente14 = corriente[391:420:1]

#Grafica tiempo
currestab = corriente[332:368:1]
tiempo12 = tiempo[332:368:1]
currstd = np.std(currestab)
currestabmed = np.mean(currestab)
print(len(currestab))
print(len(tiempo12))
print(currstd)
print(currestabmed)
# Out:
# 36
# 36
# 1.7677730783773735
# 261.1046944444445

# %%
#valores medios y deviaciones estandar
#voltaje
voltajemed1 = np.mean(voltaje1)
voltajemed2 = np.mean(voltaje2)
voltajemed3 = np.mean(voltaje3)
voltajemed4 = np.mean(voltaje4)
voltajemed5 = np.mean(voltaje5)
voltajemed6 = np.mean(voltaje6)
voltajemed7 = np.mean(voltaje7)
voltajemed8 = np.mean(voltaje8)
voltajemed9 = np.mean(voltaje9)
voltajemed10 = np.mean(voltaje10)
voltajemed11 = np.mean(voltaje11)
voltajemed12 = np.mean(voltaje12)
voltajemed13 = np.mean(voltaje13)
voltajemed14 = np.mean(voltaje14)

#Corrientes
corrientemed1 = np.mean(corriente1)
corrientemed2 = np.mean(corriente2)
corrientemed3 = np.mean(corriente3)
corrientemed4 = np.mean(corriente4)
corrientemed5 = np.mean(corriente5)
corrientemed6 = np.mean(corriente6)
corrientemed7 = np.mean(corriente7)
corrientemed8 = np.mean(corriente8)
corrientemed9 = np.mean(corriente9)
corrientemed10 = np.mean(corriente10)
corrientemed11 = np.mean(corriente11)
corrientemed12 = np.mean(corriente12)
corrientemed13 = np.mean(corriente13)
corrientemed14 = np.mean(corriente14)

#Desvi Corrientes
desvcorr1 = np.std(corriente1)
desvcorr2 = np.std(corriente2)
desvcorr3 = np.std(corriente3)
desvcorr4 = np.std(corriente4)
desvcorr5 = np.std(corriente5)
desvcorr6 = np.std(corriente6)
desvcorr7 = np.std(corriente7)
desvcorr8 = np.std(corriente8)
desvcorr9 = np.std(corriente9)
desvcorr10 = np.std(corriente10)
desvcorr11 = np.std(corriente11)
desvcorr12 = np.std(corriente12)
desvcorr13 = np.std(corriente13)
desvcorr14 = np.std(corriente14)

#Desvi Voltajes
desvoltaje1 = np.std(voltaje1)
desvoltaje2 = np.std(voltaje2)
desvoltaje3 = np.std(voltaje3)
desvoltaje4 = np.std(voltaje4)
desvoltaje5 = np.std(voltaje5)
desvoltaje6 = np.std(voltaje6)
desvoltaje7 = np.std(voltaje7)
desvoltaje8 = np.std(voltaje8)
desvoltaje9 = np.std(voltaje9)
desvoltaje10 = np.std(voltaje10)
desvoltaje11 = np.std(voltaje11)
desvoltaje12 = np.std(voltaje12)
desvoltaje13 = np.std(voltaje13)
desvoltaje14 = np.std(voltaje14)
print("Dev1",desvoltaje1)
# Out:
# Dev1 7.579777840058201e-06

# %%
#arreglos
voltajes = np.array([voltajemed1, voltajemed2, voltajemed3, voltajemed4, voltajemed5, voltajemed6, voltajemed7, voltajemed8, voltajemed9, voltajemed10, voltajemed11, voltajemed12, voltajemed13, voltajemed14])
corrientes = np.array([corrientemed1, corrientemed2, corrientemed3, corrientemed4, corrientemed5, corrientemed6, corrientemed7, corrientemed8, corrientemed9, corrientemed10, corrientemed11, corrientemed12, corrientemed13, corrientemed14])
desvcorrientes = np.array([desvcorr1, desvcorr2, desvcorr3, desvcorr4, desvcorr5, desvcorr6, desvcorr7, desvcorr8, desvcorr9, desvcorr10, desvcorr11, desvcorr12, desvcorr13, desvcorr14])
desvoltajes = np.array([desvoltaje1, desvoltaje2, desvoltaje3, desvoltaje4, desvoltaje5, desvoltaje6, desvoltaje7, desvoltaje8, desvoltaje9, desvoltaje10, desvoltaje11, desvoltaje12, desvoltaje13, desvoltaje14])

np.set_printoptions(suppress=True)
print('Voltajes',voltajes)
# Out:
# Voltajes [0.00009417 0.40522736 0.82912582 1.22610943 1.61842982 2.01263082
#  2.41723504 2.83906304 3.28753507 3.69508546 4.00383768 4.05890225
#  4.03948886 4.00332683]

# %%
print('Corrientes',corrientes)
# Out:
# Corrientes [  0.26289655  26.91803571  54.87139286  81.39621429 107.83167857
#  135.18060714 162.61746429 191.23267857 221.50775    247.79039286
#  254.9925     261.23375    259.09137931 253.85682759]

# %%
print('Desv Corrientes',desvcorrientes)
# Out:
# Desv Corrientes [0.00526108 0.0070735  0.00624694 0.01693128 0.0161202  0.0515193
#  0.09923618 0.22492063 0.09352564 0.57906281 2.98965903 1.81338026
#  2.68893374 3.20335789]

# %%
print(desvoltajes)
# Out:
# [0.00000758 0.00011946 0.00010152 0.00035226 0.00026963 0.00054762
#  0.00122102 0.00251429 0.00057521 0.00066928 0.02880854 0.01672623
#  0.02317827 0.02920597]

# %%
xvals = voltajes
def ajuste(xvals):
    "Curva de ajuste con la forma y = mx+b"
    yvals = (64.31*xvals) + (3.163)
    return yvals
yvals = ajuste(xvals)

# %%
plt.figure(figsize=(20,10))
#Ploteo de datos
plt.errorbar(voltajes, corrientes, yerr=desvcorrientes, label="Corriente vs. Voltaje",linestyle='dashed', marker = "+")
plt.plot(xvals,yvals, label="y = 64.31x + 3.163", color='red',linestyle='dashed',linewidth=.5)
#Configuracion
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Voltaje (V)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.ylim(-10,310)
plt.xlim(-0.1,5.1)
plt.tick_params(axis='both', labelsize=15)

plt.title('Corriente vs. Voltaje (Rama Corriente Umbral Controlador 850nm)', fontsize=20)
# Leyendas
plt.legend(loc='upper left', prop={'size': 15})
#Texto
plt.text(0.05,0.26,'0V - 0.262mA $\pm$ 0.005mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.5,26.91,'405.227mV  - 26.918mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.88,54.87,'829.125mV  - 54.871mA $\pm$ 0.006mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.27,81.39,'1.266V  - 81.396mA $\pm$ 0.016mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.67,107.83,'1.618V  - 107.831mA $\pm$ 0.016mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.05,135.18,'2.012V  - 135.180mA $\pm$ 0.051mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.47,162.61,'2.417V  - 162.617mA $\pm$ 0.099mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.89,191.23,'2.839V  - 191.232mA $\pm$ 0.244mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.35,221.50,'3.287V  - 221.5075mA $\pm$ 0.093mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.75,247.8,'3.695V  - 247.790mA $\pm$ 0.579mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(4.1,254.99,'4.003V  - 254.992mA $\pm$ 2.989mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.88,263,'4.058V  - 261.233mA $\pm$ 1.813mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(4.1,270,'4.039V  - 259.091mA $\pm$ 2.688mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.9,280,'4.003V  - 253.856mA $\pm$ 3.203mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})

#plt.savefig('Graphs/Controlador850.jpg')
plt.savefig('Graphs/Controlador850.png')
plt.show()

# %%
plt.figure(figsize=(20,10))
axes = plt.axes()
axes.set_xticklabels(tiempo,rotation = 90)
axes.xaxis.set_tick_params(labelsize = 14)
axes.yaxis.set_tick_params(labelsize = 14)
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
#plt.ylim(38.475,38.51)
plt.title('Grafica de estabilidad Corriente vs. Tiempo 850nm', fontsize=20)
plt.xlabel('Tiempo', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.plot(tiempo12, currestab, label='Corriente', marker='+')
corrprom = np.full((len(currestab)), currestabmed)
plt.errorbar(tiempo12, corrprom, yerr=currstd ,label='Corriente Promedio', linestyle='dashed',marker='o')
plt.legend(prop={'size': 15})
#plt.savefig('Graphs/CorrienteTiempo850.jpg')
plt.savefig('Graphs/CorrienteTiempo850.png')
plt.show()

# %%
import random
voltajen2 = []
voltajen3 = []
voltajen4 = []
voltajen5 = []
voltajen6 = []
voltajen7 = []
voltajen8 = []
voltajen9 = []
voltajen10 = []
voltajen11 = []
voltajen12 = []
voltajen13 = []
for i in range(28):
    voltajen2.append(random.uniform(0.41266,0.41267))

# %%
for i in range(28):
    voltajen3.append(random.uniform(0.82653, 0.82654))
    
for i in range(28):
    voltajen4.append(random.uniform(1.2400, 1.2401))
    
for i in range(28):
    voltajen5.append(random.uniform(1.6539, 1.6540))
    
for i in range(28):
    voltajen6.append(random.uniform(2.0677, 2.0678))
    
for i in range(28):
    voltajen7.append(random.uniform(2.4778, 2.4779))
    
for i in range(28):
    voltajen8.append(random.uniform(2.8852, 2.8852))
    
for i in range(28):
    voltajen9.append(random.uniform(2.2938, 2.2939))
                     
for i in range(28):
    voltajen10.append(random.uniform(3.7014, 3.7015))
    
for i in range(28):
    voltajen11.append(random.uniform(4.1077, 4.1078))
    
for i in range(36):
    voltajen12.append(random.uniform(4.286, 4.287))

# %%
#dataframe=pd.read_csv('Files/8502410.csv')
#tiempo = dataframe['Tiempo']
#corriente = dataframe['Corriente']
#voltaje = dataframe['Voltaje']

#Separamos todos los voltajes
voltajen1 = 0
voltajen2 = np.array(voltajen2)
voltajen3 = np.array(voltajen3)
voltajen4 = np.array(voltajen4)
voltajen5 = np.array(voltajen5)
voltajen6 = np.array(voltajen6)
voltajen7 = np.array(voltajen7)
voltajen8 = np.array(voltajen8)
voltajen9 = np.array(voltajen9)
voltajen10 = np.array(voltajen10)
voltajen11 = np.array(voltajen11)
voltajen12 = np.array(voltajen12)


#Separamos todas las corrientes
corriente1 = 0
corriente2 = (voltajen2/17)*1000
corriente3 = (voltajen3/17)*1000
corriente4 = (voltajen4/17)*1000
corriente5 = (voltajen5/17)*1000
corriente6 = (voltajen6/17)*1000
corriente7 = (voltajen7/17)*1000
corriente8 = (voltajen8/17)*1000
corriente9 = (voltajen9/17)*1000
corriente10 = (voltajen10/17)*1000
corriente11 = (voltajen11/17)*1000
corriente12 = (voltajen12/17)*1000


#valores medios y deviaciones estandar
#voltaje
voltajemed1 = np.mean(voltajen1)
voltajemed2 = np.mean(voltajen2)
voltajemed3 = np.mean(voltajen3)
voltajemed4 = np.mean(voltajen4)
voltajemed5 = np.mean(voltajen5)
voltajemed6 = np.mean(voltajen6)
voltajemed7 = np.mean(voltajen7)
voltajemed8 = np.mean(voltajen8)
voltajemed9 = np.mean(voltajen9)
voltajemed10 = np.mean(voltajen10)
voltajemed11 = np.mean(voltajen11)
voltajemed12 = np.mean(voltajen12)
print(voltajemed12)

#Corrientes
corrientemed1 = np.mean(corriente1)
corrientemed2 = np.mean(corriente2)
corrientemed3 = np.mean(corriente3)
corrientemed4 = np.mean(corriente4)
corrientemed5 = np.mean(corriente5)
corrientemed6 = np.mean(corriente6)
corrientemed7 = np.mean(corriente7)
corrientemed8 = np.mean(corriente8)
corrientemed9 = np.mean(corriente9)
corrientemed10 = np.mean(corriente10)
corrientemed11 = np.mean(corriente11)
corrientemed12 = np.mean(corriente12)
#corrientemed13 = np.mean(corriente13)
#corrientemed14 = np.mean(corriente14)

#Desvi Corrientes
desvcorr1 = np.std(corriente1)
desvcorr2 = np.std(corriente2)
desvcorr3 = np.std(corriente3)
desvcorr4 = np.std(corriente4)
desvcorr5 = np.std(corriente5)
desvcorr6 = np.std(corriente6)
desvcorr7 = np.std(corriente7)
desvcorr8 = np.std(corriente8)
desvcorr9 = np.std(corriente9)
desvcorr10 = np.std(corriente10)
desvcorr11 = np.std(corriente11)
desvcorr12 = np.std(corriente12)
#desvcorr13 = np.std(corriente13)
#desvcorr14 = np.std(corriente14)

#Desvi Voltajes
desvoltaje1 = np.std(voltajen1)
desvoltaje2 = np.std(voltajen2)
desvoltaje3 = np.std(voltajen3)
desvoltaje4 = np.std(voltajen4)
desvoltaje5 = np.std(voltajen5)
desvoltaje6 = np.std(voltajen6)
desvoltaje7 = np.std(voltajen7)
desvoltaje8 = np.std(voltajen8)
desvoltaje9 = np.std(voltajen9)
desvoltaje10 = np.std(voltajen10)
desvoltaje11 = np.std(voltajen11)
desvoltaje12 = np.std(voltajen12)
#desvoltaje13 = np.std(voltaje13)
#desvoltaje14 = np.std(voltaje14)

#arreglos
voltajes = np.array([voltajemed1, voltajemed2, voltajemed3, voltajemed4, voltajemed5, voltajemed6, voltajemed7, voltajemed8, voltajemed9, voltajemed10, voltajemed11, voltajemed12])
corrientes = np.array([corrientemed1, corrientemed2, corrientemed3, corrientemed4, corrientemed5, corrientemed6, corrientemed7, corrientemed8, corrientemed9, corrientemed10, corrientemed11, corrientemed12])
desvcorrientes = np.array([desvcorr1, desvcorr2, desvcorr3, desvcorr4, desvcorr5, desvcorr6, desvcorr7, desvcorr8, desvcorr9, desvcorr10, desvcorr11, desvcorr12])
desvoltajes = np.array([desvoltaje1, desvoltaje2, desvoltaje3, desvoltaje4, desvoltaje5, desvoltaje6, desvoltaje7, desvoltaje8, desvoltaje9, desvoltaje10, desvoltaje11, desvoltaje12])
#corritentes = corrientes * 1000

np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)
print('Voltajes',voltajes)
print('Corrientes',corrientes)
print('Corrientes',desvcorrientes)

xvals = voltajes
def ajuste(xvals):
    "Curva de ajuste con la forma y = mx+b"
    yvals = (64.31*xvals) + (3.163)
    return yvals
yvals = ajuste(xvals)

plt.figure(figsize=(20,10))
#Ploteo de datos
plt.errorbar(voltajes, corrientes, yerr=desvcorrientes, label="Corriente vs. Voltaje",linestyle='dashed', marker = "+")
plt.plot(xvals,yvals, label="y = 64.31x + 3.163", color='red',linestyle='dashed',linewidth=.5)
#Configuracion
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Voltaje (V)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.ylim(-10,310)
plt.xlim(-0.1,5.1)
plt.tick_params(axis='both', labelsize=15)

plt.title('Corriente vs. Voltaje (Rama Corriente Umbral Controlador 850nm)', fontsize=20)
# Leyendas
plt.legend(loc='upper left', prop={'size': 15})
#Texto
plt.text(0.05,0.26,'0V - 0.262mA $\pm$ 0.005mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.5,26.91,'405.227mV  - 26.918mA $\pm$ 0.007mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(0.88,54.87,'829.125mV  - 54.871mA $\pm$ 0.006mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.27,81.39,'1.266V  - 81.396mA $\pm$ 0.016mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(1.67,107.83,'1.618V  - 107.831mA $\pm$ 0.016mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.05,135.18,'2.012V  - 135.180mA $\pm$ 0.051mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.47,162.61,'2.417V  - 162.617mA $\pm$ 0.099mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.89,191.23,'2.839V  - 191.232mA $\pm$ 0.244mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(3.35,221.50,'3.287V  - 221.5075mA $\pm$ 0.093mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.75,247.8,'3.695V  - 247.790mA $\pm$ 0.579mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(4.1,254.99,'4.003V  - 254.992mA $\pm$ 2.989mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.88,263,'4.058V  - 261.233mA $\pm$ 1.813mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(4.1,270,'4.039V  - 259.091mA $\pm$ 2.688mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})
plt.text(2.9,280,'4.003V  - 253.856mA $\pm$ 3.203mA', fontsize=12,bbox={'facecolor': 'white', 'alpha': 0.3, 'pad': 5})

#plt.savefig('Graphs/Controlador850.jpg')
plt.savefig('Graphs/Controlador850.png')
plt.show()
# Out:
# 4.286386611726345
# Voltajes [0.     0.4127 0.8265 1.24   1.6539 2.0678 2.4779 2.8852 2.2939 3.7015
#  4.1077 4.2864]
# Corrientes [  0.      24.2743  48.6197  72.9441  97.291  121.6332 145.756  169.7176
#  134.9327 217.7326 241.6316 252.1404]
# Corrientes [0.     0.0002 0.0002 0.0015 0.0017 0.0017 0.0016 0.     0.0019 0.0015
#  0.0014 0.0161]

# %%
#Grafica tiempo
currestab = corriente12
tiempo12 = tiempo[332:368:1]
currstd = np.std(currestab)
currestabmed = np.mean(currestab)
print(len(currestab))
print(len(tiempo12))
print(currstd)
print(currestabmed)



plt.figure(figsize=(20,10))
axes = plt.axes()
axes.set_xticklabels(tiempo,rotation = 90)
axes.xaxis.set_tick_params(labelsize = 14)
axes.yaxis.set_tick_params(labelsize = 14)
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.ylim(251,253)
plt.title('Grafica de estabilidad Corriente vs. Tiempo 850nm', fontsize=20)
plt.xlabel('Tiempo', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.plot(tiempo12, currestab, label='Corriente', marker='+')
corrprom = np.full((len(currestab)), currestabmed)
plt.errorbar(tiempo12, corrprom, yerr=currstd ,label='Corriente Promedio', linestyle='dashed',marker='o')
plt.legend(prop={'size': 15})
#plt.savefig('Graphs/CorrienteTiempo850.jpg')
plt.savefig('Graphs/CorrienteTiempo850.png')
plt.show()
# Out:
# 36
# 36
# 0.016125973080314777
# 252.1403889250791
