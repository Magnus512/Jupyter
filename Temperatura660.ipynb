# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from datetime import datetime

# %%
dataframe=pd.read_csv('Files/Temperatura660.csv')

# %%
corriente = dataframe['Corriente']
temperatura = dataframe['Temperatura']
corriente = corriente * 1000
corriente = corriente[341:676:1]
temperatura = temperatura[341:676:1]
# Out:
# 341    25.80
# 342    25.79
# 343    25.76
# 344    25.88
# 345    25.76
#        ...
# 671    26.24
# 672    26.20
# 673    26.18
# 674    26.26
# 675    26.18
# Name: Temperatura, Length: 335, dtype: float64
# 341    42.565890
# 342    42.560272
# 343    42.556532
# 344    42.555403
# 345    42.554405
#          ...
# 671    42.381875
# 672    42.382385
# 673    42.380858
# 674    42.378362
# 675    42.377181
# Name: Corriente, Length: 335, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.minorticks_on()
plt.grid(which='major',linestyle='-')
plt.grid(which='minor',linestyle=':')
plt.xlabel('Temperatura (°C)', fontsize=20)
plt.ylabel('Corriente (mA)', fontsize=20)
plt.tick_params(axis='both', labelsize=15)
#plt.ylim(0,65)
plt.xlim(25.7,26.3)
plt.scatter(temperatura,corriente)
plt.show()
